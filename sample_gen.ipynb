# %% [markdown]
# # じゃらんデータ整備のためにサンプルデータを作る

# %% [markdown]
# ## データの読み込み

# %%
import csv
# csv_file出力
import os
import pandas as pd
# Shift-JIS 形式の CSV ファイル (employee.sjis.csv) して出力
# df.to_csv("employee.sjis.csv", encoding="shift_jis")
# csvを開く。

os.chdir("D:\じゃらん宿泊データ\original_data")

csv_file_name = "hotel_res2021-04-01.csv"
columns = ["エリアコード","宿コード","データ取得日","チェックイン日","プランコード","価格","部屋情報","朝食の有無","夕食の有無","チェックイン時刻","チェックアウト時刻","プラン提供開始日","プラン提供終了日","イメージ画像URL","画像キャプション","残り部屋数"]

df = pd.read_csv(csv_file_name,names=(columns))
df.head()
# Out:
#    エリアコード    宿コード      データ取得日     チェックイン日   プランコード    価格  \
# 0   10202  300206  2021-04-01  2021-04-01   630738  3600
# 1   10202  300206  2021-04-01  2021-04-01   630738  3700
# 2   10202  300206  2021-04-01  2021-04-01   630738  4100
# 3   10202  302905  2021-04-01  2021-04-01  3102459  8000
# 4   10202  302905  2021-04-01  2021-04-01  3102459  8000
#
#                                  部屋情報  朝食の有無  夕食の有無 チェックイン時刻 チェックアウト時刻  \
# 0    【1名利用】ダブルorツインルーム　2020年2月リニューアル済      0      0    15:00     11:00
# 1  　禁煙ダブルルーム　2020年客室リニューアル完了（15～17平米）      0      0    15:00     11:00
# 2      禁煙ツインルーム　2020年客室リニューアル完了（18平米）      0      0    15:00     11:00
# 3            リニューアルフロア・ツイン/アーバン＜２３平米＞      0      0    15:00     11:00
# 4          スタンダードフロア・ツイン＜アーバンルーム＞２３平米      0      0    15:00     11:00
#
#    プラン提供開始日  プラン提供終了日                                          イメージ画像URL  \
# 0  20080916  20220228  https://www.jalan.net/jalan/images/pictM/Y6/Y3...
# 1  20111118  20220228  https://www.jalan.net/jalan/images/pictM/Y6/Y3...
# 2  20080916  20220228  https://www.jalan.net/jalan/images/pictM/Y6/Y3...
# 3  20210220  20210531  https://www.jalan.net/jalan/images/pictM/Y5/Y3...
# 4  20210220  20210531  https://www.jalan.net/jalan/images/pictM/Y5/Y3...
#
#              画像キャプション  残り部屋数
# 0    ダブルルーム　ベッド幅140cm    NaN
# 1   ダブルルーム　　ベッド幅140cm    NaN
# 2  ツインルーム　　　ベッド幅120cm    6.0
# 3   期間限定＆室数限定のお得なプラン♪    2.0
# 4   期間限定＆室数限定のお得なプラン♪    2.0

# %% [markdown]
# ## データを10000行だけ抽出

# %%
df_sample = df.iloc[:10000]
# df_sample = df.copy()

# %% [markdown]
# ## テキストをまとめて元のデータを削除

# %%
text = df_sample["部屋情報"] + df_sample["画像キャプション"]
df_s_text = pd.DataFrame(text,columns=["text"])
df_s_text
# Out:
#                                                    text
# 0      【1名利用】ダブルorツインルーム　2020年2月リニューアル済ダブルルーム　ベッド幅140cm
# 1     　禁煙ダブルルーム　2020年客室リニューアル完了（15～17平米）ダブルルーム　　ベッド幅...
# 2      禁煙ツインルーム　2020年客室リニューアル完了（18平米）ツインルーム　　　ベッド幅120cm
# 3             リニューアルフロア・ツイン/アーバン＜２３平米＞期間限定＆室数限定のお得なプラン♪
# 4           スタンダードフロア・ツイン＜アーバンルーム＞２３平米期間限定＆室数限定のお得なプラン♪
# ...                                                 ...
# 9995        【最上階/道庁側】スーペリアツイン　２６平米　＜禁煙＞期間限定のお得なプランはこちら！
# 9996  【最上階/道庁側】スーペリアツイン　２６平米　＜禁煙＞最上階スーペリアツイン(26平米/シン...
# 9997  【最上階/道庁側】スーペリアツイン　２６平米　＜禁煙＞最上階スーペリアツイン(26平米/シン...
# 9998        【最上階/道庁側】プレミアムツイン　５６平米　＜禁煙＞期間限定のお得なプランはこちら！
# 9999  【最上階/道庁側】プレミアムツイン　５６平米　＜禁煙＞最上階のプレミアムツイン、スーペリアダ...
#
# [10000 rows x 1 columns]

# %%
df_s = df_sample.drop(columns=["部屋情報","イメージ画像URL","画像キャプション"])
df_s = pd.concat([df_s, df_s_text], axis=1)
df_s
# Out:
#       エリアコード    宿コード      データ取得日     チェックイン日   プランコード     価格  朝食の有無  夕食の有無  \
# 0      10202  300206  2021-04-01  2021-04-01   630738   3600      0      0
# 1      10202  300206  2021-04-01  2021-04-01   630738   3700      0      0
# 2      10202  300206  2021-04-01  2021-04-01   630738   4100      0      0
# 3      10202  302905  2021-04-01  2021-04-01  3102459   8000      0      0
# 4      10202  302905  2021-04-01  2021-04-01  3102459   8000      0      0
# ...      ...     ...         ...         ...      ...    ...    ...    ...
# 9995   10202  333592  2021-04-01  2021-04-02  3104821  19950      1      0
# 9996   10202  333592  2021-04-01  2021-04-02  2968018  24700      1      0
# 9997   10202  333592  2021-04-01  2021-04-02  2967803  27500      1      0
# 9998   10202  333592  2021-04-01  2021-04-02  3104821  42750      1      0
# 9999   10202  333592  2021-04-01  2021-04-02  2968018  54700      1      0
#
#      チェックイン時刻 チェックアウト時刻  プラン提供開始日  プラン提供終了日  残り部屋数  \
# 0       15:00     11:00  20080916  20220228    NaN
# 1       15:00     11:00  20111118  20220228    NaN
# 2       15:00     11:00  20080916  20220228    6.0
# 3       15:00     11:00  20210220  20210531    2.0
# 4       15:00     11:00  20210220  20210531    2.0
# ...       ...       ...       ...       ...    ...
# 9995    15:00     11:00  20210210  20210630    3.0
# 9996    15:00     11:00  20210201  20210427    3.0
# 9997    15:00     11:00  20210201  20220228    3.0
# 9998    15:00     11:00  20210210  20210630    1.0
# 9999    15:00     11:00  20210201  20210427    1.0
#
#                                                    text
# 0      【1名利用】ダブルorツインルーム　2020年2月リニューアル済ダブルルーム　ベッド幅140cm
# 1     　禁煙ダブルルーム　2020年客室リニューアル完了（15～17平米）ダブルルーム　　ベッド幅...
# 2      禁煙ツインルーム　2020年客室リニューアル完了（18平米）ツインルーム　　　ベッド幅120cm
# 3             リニューアルフロア・ツイン/アーバン＜２３平米＞期間限定＆室数限定のお得なプラン♪
# 4           スタンダードフロア・ツイン＜アーバンルーム＞２３平米期間限定＆室数限定のお得なプラン♪
# ...                                                 ...
# 9995        【最上階/道庁側】スーペリアツイン　２６平米　＜禁煙＞期間限定のお得なプランはこちら！
# 9996  【最上階/道庁側】スーペリアツイン　２６平米　＜禁煙＞最上階スーペリアツイン(26平米/シン...
# 9997  【最上階/道庁側】スーペリアツイン　２６平米　＜禁煙＞最上階スーペリアツイン(26平米/シン...
# 9998        【最上階/道庁側】プレミアムツイン　５６平米　＜禁煙＞期間限定のお得なプランはこちら！
# 9999  【最上階/道庁側】プレミアムツイン　５６平米　＜禁煙＞最上階のプレミアムツイン、スーペリアダ...
#
# [10000 rows x 14 columns]

# %%
len(df_s)
# Out:
# 10000

# %% [markdown]
# ## フラグの追加

# %% [markdown]
# #やや遅い
# kinnen = []
# kitsuen = []
# wa = []
# yo = []
# wayo = []
# single = []
# semidouble = []
# double = []
# twin = []
# tri = []
# omakase = []
# renpaku = []
#
# for text in df_s["text"]:
#     text = str(text)
#     kinnen.append(int("禁煙" in text))
#     kitsuen.append(int("喫煙" in text))
#     wa.append(int("和室" in text))
#     yo_wa = int("和洋室" in text) + int("洋室" in text)
#     if yo_wa == 2:
#         wayo.append(1)
#         yo.append(0)
#     elif yo_wa == 1:
#         wayo.append(0)
#         yo.append(1)
#     else:
#         wayo.append(0)
#         yo.append(0)
#     single.append(int("シングル" in text))
#     semi_dou = int("セミダブル" in text) + int("ダブル" in text)
#     if semi_dou == 2:
#         semidouble.append(1)
#         double.append(0)
#     elif semi_dou == 1:
#         semidouble.append(0)
#         double.append(1)
#     else:
#         semidouble.append(0)
#         double.append(0)
#     twin.append(int("ツイン" in text))
#     tri.append(int("トリプル" in text))
#     omakase.append(int("おまかせ" in text))
#     renpaku.append(int("連泊" in text))
#
# #print(kinnen)
# #print(kituen)
# df_kinnen = pd.DataFrame(kinnen,columns=["禁煙"])
# df_kitsuen = pd.DataFrame(kitsuen,columns=["喫煙"])
# df_wa =  pd.DataFrame(wa,columns=["和室"])
# df_yo =  pd.DataFrame(yo,columns=["洋室"])
# df_wayo =  pd.DataFrame(wayo,columns=["和洋室"])
# df_single =  pd.DataFrame(single,columns=["シングル"])
# df_semidouble =  pd.DataFrame(semidouble,columns=["セミダブル"])
# df_double =  pd.DataFrame(double,columns=["ダブル"])
# df_twin =  pd.DataFrame(twin,columns=["ツイン"])
# df_tri =  pd.DataFrame(tri,columns=["トリプル"])
# df_omakase =  pd.DataFrame(omakase,columns=["おまかせ"])
# df_renpaku = pd.DataFrame(renpaku,columns=["連泊"])
# df_s = pd.concat([df_s,df_kinnen,df_kitsuen,df_wa,df_yo,df_wayo,df_single,df_semidouble,df_double,df_twin,df_tri,df_omakase,df_renpaku], axis=1)
# df_s = df_s.drop(columns="text")
# df_s

# %%
# こっちの方が20%速い
import numpy as np

kinnen = []
kitsuen = []
wa = []
yo = []
wayo = []
single = []
semidouble = []
double = []
twin = []
tri = []
omakase = []
renpaku = []

for text in df_s["text"]:
    text = str(text)
    kinnen.append(int("禁煙" in text))
    kitsuen.append(int("喫煙" in text))
    wa.append(int("和室" in text))
    yo_wa = int("和洋室" in text) + int("洋室" in text)
    if yo_wa == 2:
        wayo.append(1)
        yo.append(0)
    elif yo_wa == 1:
        wayo.append(0)
        yo.append(1)
    else:
        wayo.append(0)
        yo.append(0)
    single.append(int("シングル" in text))
    semi_dou = int("セミダブル" in text) + int("ダブル" in text)
    if semi_dou == 2:
        semidouble.append(1)
        double.append(0)
    elif semi_dou == 1:
        semidouble.append(0)
        double.append(1)
    else:
        semidouble.append(0)
        double.append(0)        
    twin.append(int("ツイン" in text))
    tri.append(int("トリプル" in text))
    omakase.append(int("おまかせ" in text))
    renpaku.append(int("連泊" in text))
add_list = [kinnen,kitsuen,wa,yo,wayo,single,semidouble,double,twin,tri,omakase,renpaku]
add_list = np.array(add_list).T
df_add = pd.DataFrame(add_list,columns = ["禁煙","喫煙","和室","洋室","和洋室","シングル","セミダブル","ダブル","ツイン","トリプル","おまかせ","連泊"])
df_s = pd.concat([df_s,df_add], axis=1)
df_s = df_s.drop(columns="text")
df_s
# Out:
#       エリアコード    宿コード      データ取得日     チェックイン日   プランコード     価格  朝食の有無  夕食の有無  \
# 0      10202  300206  2021-04-01  2021-04-01   630738   3600      0      0
# 1      10202  300206  2021-04-01  2021-04-01   630738   3700      0      0
# 2      10202  300206  2021-04-01  2021-04-01   630738   4100      0      0
# 3      10202  302905  2021-04-01  2021-04-01  3102459   8000      0      0
# 4      10202  302905  2021-04-01  2021-04-01  3102459   8000      0      0
# ...      ...     ...         ...         ...      ...    ...    ...    ...
# 9995   10202  333592  2021-04-01  2021-04-02  3104821  19950      1      0
# 9996   10202  333592  2021-04-01  2021-04-02  2968018  24700      1      0
# 9997   10202  333592  2021-04-01  2021-04-02  2967803  27500      1      0
# 9998   10202  333592  2021-04-01  2021-04-02  3104821  42750      1      0
# 9999   10202  333592  2021-04-01  2021-04-02  2968018  54700      1      0
#
#      チェックイン時刻 チェックアウト時刻  ...  和室  洋室  和洋室  シングル  セミダブル  ダブル  ツイン  トリプル  おまかせ  \
# 0       15:00     11:00  ...   0   0    0     0      0    1    1     0     0
# 1       15:00     11:00  ...   0   0    0     0      0    1    0     0     0
# 2       15:00     11:00  ...   0   0    0     0      0    0    1     0     0
# 3       15:00     11:00  ...   0   0    0     0      0    0    1     0     0
# 4       15:00     11:00  ...   0   0    0     0      0    0    1     0     0
# ...       ...       ...  ...  ..  ..  ...   ...    ...  ...  ...   ...   ...
# 9995    15:00     11:00  ...   0   0    0     0      0    0    1     0     0
# 9996    15:00     11:00  ...   0   0    0     1      0    0    1     0     0
# 9997    15:00     11:00  ...   0   0    0     1      0    0    1     0     0
# 9998    15:00     11:00  ...   0   0    0     0      0    0    1     0     0
# 9999    15:00     11:00  ...   0   0    0     0      0    1    1     0     0
#
#       連泊
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# ...   ..
# 9995   0
# 9996   0
# 9997   0
# 9998   0
# 9999   0
#
# [10000 rows x 25 columns]

# %%
df_s.describe()
# Out:
#         エリアコード           宿コード        プランコード             価格         朝食の有無  \
# count  10000.0   10000.000000  1.000000e+04   10000.000000  10000.000000
# mean   10202.0  333842.110400  2.554062e+06   11392.887600      0.514500
# std        0.0   23587.318207  7.109131e+05   11036.929662      0.499815
# min    10202.0  300206.000000  9.798000e+03    1800.000000      0.000000
# 25%    10202.0  321150.000000  2.349554e+06    6000.000000      0.000000
# 50%    10202.0  326891.000000  2.866070e+06    8300.000000      1.000000
# 75%    10202.0  340127.000000  3.060187e+06   12500.000000      1.000000
# max    10202.0  398940.000000  3.144670e+06  165000.000000      1.000000
#
#               夕食の有無      プラン提供開始日      プラン提供終了日        残り部屋数           禁煙  \
# count  10000.000000  1.000000e+04  1.000000e+04  7381.000000  10000.00000
# mean       0.026800  2.018554e+07  2.021360e+07     3.511313      0.62940
# std        0.161507  3.198326e+04  4.251870e+03     2.129936      0.48299
# min        0.000000  2.007022e+07  2.021040e+07     1.000000      0.00000
# 25%        0.000000  2.018041e+07  2.021083e+07     2.000000      0.00000
# 50%        0.000000  2.020052e+07  2.021103e+07     3.000000      1.00000
# 75%        0.000000  2.021011e+07  2.022013e+07     5.000000      1.00000
# max        1.000000  2.021040e+07  2.022033e+07     9.000000      1.00000
#
#        ...           和室            洋室          和洋室          シングル  \
# count  ...  10000.00000  10000.000000  10000.00000  10000.000000
# mean   ...      0.00580      0.009200      0.00110      0.240200
# std    ...      0.07594      0.095479      0.03315      0.427226
# min    ...      0.00000      0.000000      0.00000      0.000000
# 25%    ...      0.00000      0.000000      0.00000      0.000000
# 50%    ...      0.00000      0.000000      0.00000      0.000000
# 75%    ...      0.00000      0.000000      0.00000      0.000000
# max    ...      1.00000      1.000000      1.00000      1.000000
#
#               セミダブル           ダブル           ツイン         トリプル          おまかせ  \
# count  10000.000000  10000.000000  10000.000000  10000.00000  10000.000000
# mean       0.042900      0.243700      0.401900      0.00990      0.010000
# std        0.202642      0.429335      0.490306      0.09901      0.099504
# min        0.000000      0.000000      0.000000      0.00000      0.000000
# 25%        0.000000      0.000000      0.000000      0.00000      0.000000
# 50%        0.000000      0.000000      0.000000      0.00000      0.000000
# 75%        0.000000      0.000000      1.000000      0.00000      0.000000
# max        1.000000      1.000000      1.000000      1.00000      1.000000
#
#             連泊
# count  10000.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
#
# [8 rows x 21 columns]

# %%
df_630738	 = df_s[df_s['プランコード'] == 630738]
print(df_630738)
# Out:
#       エリアコード    宿コード      データ取得日     チェックイン日  プランコード    価格  朝食の有無  夕食の有無  \
# 0      10202  300206  2021-04-01  2021-04-01  630738  3600      0      0
# 1      10202  300206  2021-04-01  2021-04-01  630738  3700      0      0
# 2      10202  300206  2021-04-01  2021-04-01  630738  4100      0      0
# 6206   10202  300206  2021-04-01  2021-04-02  630738  3600      0      0
# 6207   10202  300206  2021-04-01  2021-04-02  630738  3700      0      0
# 6208   10202  300206  2021-04-01  2021-04-02  630738  4100      0      0
#
#      チェックイン時刻 チェックアウト時刻  ...  和室  洋室  和洋室  シングル  セミダブル  ダブル  ツイン  トリプル  おまかせ  \
# 0       15:00     11:00  ...   0   0    0     0      0    1    1     0     0
# 1       15:00     11:00  ...   0   0    0     0      0    1    0     0     0
# 2       15:00     11:00  ...   0   0    0     0      0    0    1     0     0
# 6206    15:00     11:00  ...   0   0    0     0      0    1    1     0     0
# 6207    15:00     11:00  ...   0   0    0     0      0    1    0     0     0
# 6208    15:00     11:00  ...   0   0    0     0      0    0    1     0     0
#
#       連泊
# 0      0
# 1      0
# 2      0
# 6206   0
# 6207   0
# 6208   0
#
# [6 rows x 25 columns]

# %% [markdown]
# ## プランコードを作成する。

# %%
df_s.columns
# Out:
# Index(['エリアコード', '宿コード', 'データ取得日', 'チェックイン日', 'プランコード', '価格', '朝食の有無', '夕食の有無',
#        'チェックイン時刻', 'チェックアウト時刻', 'プラン提供開始日', 'プラン提供終了日', '残り部屋数', '禁煙', '喫煙',
#        '和室', '洋室', '和洋室', 'シングル', 'セミダブル', 'ダブル', 'ツイン', 'トリプル', 'おまかせ', '連泊'],
#       dtype='object')

# %%
plan_code_columns = ['朝食の有無','夕食の有無','チェックイン時刻','チェックアウト時刻','プラン提供開始日', 'プラン提供終了日', '禁煙','喫煙','和室','洋室', '和洋室', 'シングル', 'セミダブル', 'ダブル', 'ツイン', 'トリプル', 'おまかせ', '連泊']

# %%
code = df_s['プランコード'].astype(str)
for columns_name in plan_code_columns:
    code = code + df_s[columns_name].astype(str)
df_code = pd.DataFrame(code,columns=["gen_plan_code"])
df_code
# Out:
#                                         gen_plan_code
# 0      6307380015:0011:002008091620220228000000011000
# 1      6307380015:0011:002011111820220228100000010000
# 2      6307380015:0011:002008091620220228100000001000
# 3     31024590015:0011:002021022020210531000000001000
# 4     31024590015:0011:002021022020210531000000001000
# ...                                               ...
# 9995  31048211015:0011:002021021020210630100000001000
# 9996  29680181015:0011:002021020120210427100001001000
# 9997  29678031015:0011:002021020120220228100001001000
# 9998  31048211015:0011:002021021020210630100000001000
# 9999  29680181015:0011:002021020120210427100000011000
#
# [10000 rows x 1 columns]

# %%
df_s = df_s.drop(columns=['プランコード','朝食の有無','夕食の有無','チェックイン時刻','チェックアウト時刻','プラン提供開始日', 'プラン提供終了日','禁煙','喫煙','和室','洋室', '和洋室', 'シングル', 'セミダブル', 'ダブル', 'ツイン', 'トリプル', 'おまかせ', '連泊'])
df_s = pd.concat([df_s, df_code], axis=1)
df_s
# Out:
#       エリアコード    宿コード      データ取得日     チェックイン日     価格  残り部屋数  \
# 0      10202  300206  2021-04-01  2021-04-01   3600    NaN
# 1      10202  300206  2021-04-01  2021-04-01   3700    NaN
# 2      10202  300206  2021-04-01  2021-04-01   4100    6.0
# 3      10202  302905  2021-04-01  2021-04-01   8000    2.0
# 4      10202  302905  2021-04-01  2021-04-01   8000    2.0
# ...      ...     ...         ...         ...    ...    ...
# 9995   10202  333592  2021-04-01  2021-04-02  19950    3.0
# 9996   10202  333592  2021-04-01  2021-04-02  24700    3.0
# 9997   10202  333592  2021-04-01  2021-04-02  27500    3.0
# 9998   10202  333592  2021-04-01  2021-04-02  42750    1.0
# 9999   10202  333592  2021-04-01  2021-04-02  54700    1.0
#
#                                         gen_plan_code
# 0      6307380015:0011:002008091620220228000000011000
# 1      6307380015:0011:002011111820220228100000010000
# 2      6307380015:0011:002008091620220228100000001000
# 3     31024590015:0011:002021022020210531000000001000
# 4     31024590015:0011:002021022020210531000000001000
# ...                                               ...
# 9995  31048211015:0011:002021021020210630100000001000
# 9996  29680181015:0011:002021020120210427100001001000
# 9997  29678031015:0011:002021020120220228100001001000
# 9998  31048211015:0011:002021021020210630100000001000
# 9999  29680181015:0011:002021020120210427100000011000
#
# [10000 rows x 7 columns]

# %% [markdown]
# ## サンプルデータをcsvファイルで保存

# %%
os.chdir("D:\じゃらん宿泊データ\sample_data")
df_s.to_csv(csv_file_name)
